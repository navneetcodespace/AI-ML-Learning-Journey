# %%
import numpy as np
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import numpy as np
# ----> 2 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# Creating a DataFrame -> Combination of multiple Series

# %%
data = {
    'Name':['john','navneet','rahul','priya'],
    'Age':[28,22,29,32],
    'City':['mumbai','delhi','noida','Mumbai'],
    'Salary':[65000,70000,28000,60000]
}

# %%
df = pd.DataFrame(data)

# %%
data_list = [
    ['john',28,'New York', 65000],
    ['Navneet',23,'Delhi',30000],
    ['ivaann',26,'Gudgaon',20000],
    ['rohit',30,'Mumbai',30000]
]

# %%
df2 = pd.DataFrame(data_list)
df2
# Out:
#          0   1         2      3
# 0     john  28  New York  65000
# 1  Navneet  23     Delhi  30000
# 2   ivaann  26   Gudgaon  20000
# 3    rohit  30    Mumbai  30000

# %%
columns = ["name","age","city","salary"]

# %%
df2 = pd.DataFrame(data_list,columns = columns)
df2
# Out:
#       name  age      city  salary
# 0     john   28  New York   65000
# 1  Navneet   23     Delhi   30000
# 2   ivaann   26   Gudgaon   20000
# 3    rohit   30    Mumbai   30000

# %% [markdown]
# **Section and indexing of column**

# %%
df2
# Out:
#       name  age      city  salary
# 0     john   28  New York   65000
# 1  Navneet   23     Delhi   30000
# 2   ivaann   26   Gudgaon   20000
# 3    rohit   30    Mumbai   30000

# %%
df2['name']
# Out:
# 0       john
# 1    Navneet
# 2     ivaann
# 3      rohit
# Name: name, dtype: str

# %%
df2['city']
# Out:
# 0    New York
# 1       Delhi
# 2     Gudgaon
# 3      Mumbai
# Name: city, dtype: str

# %%
df2[['name','city']]
# Out:
#       name      city
# 0     john  New York
# 1  Navneet     Delhi
# 2   ivaann   Gudgaon
# 3    rohit    Mumbai

# %% [markdown]
# Creating a new column

# %%
df2['Designation'] = ['HR','IT','HR','Tech-Support']
#yaha pr jaise selction k time krte hain same wahi krenge but ab = lga kr values assign krenge, dhyan rahe values same honi cahiye jitne rows hain, wrna error aa jayega.

# %%
df2
# Out:
#       name  age      city  salary   Designation
# 0     john   28  New York   65000            HR
# 1  Navneet   23     Delhi   30000            IT
# 2   ivaann   26   Gudgaon   20000            HR
# 3    rohit   30    Mumbai   30000  Tech-Support

# %% [markdown]
# Removing Columns

# %%
df2.drop('Designation', axis=1)
#in dataframe agr axis nahi dete to axis 0 hota , jo ki horizontal hota hai too wo "Designation" ko horizontali check krta hai.

#.drop se main data se remove nahi hota bs ek copy deikhata hai.
# Out:
#       name  age      city  salary
# 0     john   28  New York   65000
# 1  Navneet   23     Delhi   30000
# 2   ivaann   26   Gudgaon   20000
# 3    rohit   30    Mumbai   30000

# %%
df2.drop('Designation', axis=1,inplace=True)

#inplace ka use krke hum isko original dataframe se bhi delete kr skte hain.

# %%
#Can we drop multiple column ?
#yes.
df2.drop(['city','age'], axis=1)
# Out:
#       name  salary
# 0     john   65000
# 1  Navneet   30000
# 2   ivaann   20000
# 3    rohit   30000

# %%
#delete rows
df2.drop(0, axis=0)
# Out:
#       name  age     city  salary
# 1  Navneet   23    Delhi   30000
# 2   ivaann   26  Gudgaon   20000
# 3    rohit   30   Mumbai   30000

# %%
df2
# Out:
#       name  age      city  salary
# 0     john   28  New York   65000
# 1  Navneet   23     Delhi   30000
# 2   ivaann   26   Gudgaon   20000
# 3    rohit   30    Mumbai   30000

# %% [markdown]
# Selecting Rows

# %%
df2
# Out:
#       name  age      city  salary
# 0     john   28  New York   65000
# 1  Navneet   23     Delhi   30000
# 2   ivaann   26   Gudgaon   20000
# 3    rohit   30    Mumbai   30000

# %%
df2.loc[0]
#.loc - location for rows
# Out:
# name          john
# age             28
# city      New York
# salary       65000
# Name: 0, dtype: object

# %%
df2.loc[[0,1]]
# Out:
#       name  age      city  salary
# 0     john   28  New York   65000
# 1  Navneet   23     Delhi   30000

# %%
df2.iloc[3] #index location
# Out:
# name       rohit
# age           30
# city      Mumbai
# salary     30000
# Name: 3, dtype: object

# %% [markdown]
# Selecting Subsets of Rows and Columns

# %%
df2.loc[[0,1]][['city','salary']]
# Out:
#        city  salary
# 0  New York   65000
# 1     Delhi   30000

# %%
df2.loc[[2,3]][['name','age']]
# Out:
#      name  age
# 2  ivaann   26
# 3   rohit   30

# %% [markdown]
# ## **Conditional Selection**

# %%
df2
# Out:
#       name  age      city  salary
# 0     john   28  New York   65000
# 1  Navneet   23     Delhi   30000
# 2   ivaann   26   Gudgaon   20000
# 3    rohit   30    Mumbai   30000

# %%
df2[df2['age'] > 25]
# Out:
#      name  age      city  salary
# 0    john   28  New York   65000
# 2  ivaann   26   Gudgaon   20000
# 3   rohit   30    Mumbai   30000

# %%
df2[ ( df2['age'] > 25 ) & ( df2['city'] == 'Mumbai' ) ]
# Out:
#     name  age    city  salary
# 3  rohit   30  Mumbai   30000
