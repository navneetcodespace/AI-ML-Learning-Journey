# %% [markdown]
# # **Pandas Series**  - >
#
# ##     A series is a one - dimensional labbeled array capable of holding any data types.The axis are collectively called the index.

# %%
# !pip install pandas

# %% [markdown]
# ## **Creating Series ->**
#
# _There are multiple way to create a pandas series._

# %%
import numpy as np
import pandas as pd

# %%
labels = ['a','b','c']
my_list = [10,20,30]
my_arr = np.array([10,20,30])
d = {1:10,2:20,3:30}

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_list,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(my_arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64
