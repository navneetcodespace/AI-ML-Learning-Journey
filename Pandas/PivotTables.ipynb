# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Pivot Tables

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    338     40   John  January      Q1
# 1  2023-01-02       B   West    847     52   Mary  January      Q1
# 2  2023-01-03       C  North    172     42    Bob  January      Q1
# 3  2023-01-04       D  South    848     16  Alice  January      Q1
# 4  2023-01-05       A   East    447     21   John  January      Q1
# 5  2023-01-06       B   West    667     34   Mary  January      Q1
# 6  2023-01-07       C  North    546     92    Bob  January      Q1
# 7  2023-01-08       D  South    308     21  Alice  January      Q1
# 8  2023-01-09       A   East    836     82   John  January      Q1
# 9  2023-01-10       B   West    229     39   Mary  January      Q1
# 10 2023-01-11       C  North    562     41    Bob  January      Q1
# 11 2023-01-12       D  South    806     81  Alice  January      Q1
# 12 2023-01-13       A   East    719     41   John  January      Q1
# 13 2023-01-14       B   West    729     59   Mary  January      Q1
# 14 2023-01-15       C  North    371     36    Bob  January      Q1
# 15 2023-01-16       D  South    456     23  Alice  January      Q1
# 16 2023-01-17       A   East    516     85   John  January      Q1
# 17 2023-01-18       B   West    296     67   Mary  January      Q1
# 18 2023-01-19       C  North    842     55    Bob  January      Q1
# 19 2023-01-20       D  South    739     63  Alice  January      Q1

# %%
pd.pivot_table(df,values = 'Sales',index = 'Region', columns='Product', aggfunc='mean')
# Out:
# Product      A      B      C      D
# Region
# East     571.2    NaN    NaN    NaN
# North      NaN    NaN  498.6    NaN
# South      NaN    NaN    NaN  631.4
# West       NaN  553.6    NaN    NaN

# %%
pivot2 = pd.pivot_table(df,values=['Sales','Units'], index='Region', columns='Product')

pivot2


# agr aggrigate function use kr rahe hain toh values mein numeric values hi use krni hogi
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     571.2    NaN    NaN    NaN  53.8   NaN   NaN   NaN
# North      NaN    NaN  498.6    NaN   NaN   NaN  53.2   NaN
# South      NaN    NaN    NaN  631.4   NaN   NaN   NaN  40.8
# West       NaN  553.6    NaN    NaN   NaN  50.2   NaN   NaN

# %% [markdown]
# Cross Tabs

# %%
pd.crosstab(df['Region'],df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
