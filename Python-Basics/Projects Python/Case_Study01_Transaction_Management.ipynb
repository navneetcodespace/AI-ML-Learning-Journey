# %%
# step 1 : Define a dictionary

customers = {}

# %%
# step 2 : Function to add new customer

def add_customer(account_number, name, balance):
    if account_number in customers:
        print("Account already exists !")
    else:
        customers[account_number] = {"Name" : name, "Balance" : balance}
        print("Account added successfully !")

add_customer(1101,"navneet",24000)
add_customer(1102,'Mayank',20000)
add_customer(1103,'Ivaann',30000)
# Out:
# Account already exists !
# Account added successfully !
# Account added successfully !

# %%
# step 3 : Function to display customer details

def display_customer(account_number):

    if account_number in customers:
        print(f"Account number : {account_number}")
        print(f"Name : {customers[account_number]['Name']}")
        print(f"Balance : {customers[account_number]['Balance']}")

    else:
        print("Customer not found !")

# %%
display_customer(1101)
display_customer(1102)
display_customer(1103)
# Out:
# Account number : 1101
# Name : navneet
# Balance : 24000
# Account number : 1102
# Name : Mayank
# Balance : 20000
# Account number : 1103
# Name : Ivaann
# Balance : 30000

# %%
# step 4 : Update customer balance

def update_balance(account_number, amount, transaction_type):
    if account_number in customers:
        if transaction_type == "deposite":
            customers[account_number]["Balance"] += amount
        elif transaction_type == "withdraw" and customers[account_number]["Balance"] >= amount:
            customers[account_number]["Balance"] -= amount
        else:
            print("Insufficient balance!")
        print("Transaction successful!")
    else:
        print("Account not found!")

# %%
update_balance(1101,500,"deposite")
# Out:
# Transaction successful!

# %%
display_customer(1101)
# Out:
# Account number : 1101
# Name : navneet
# Balance : 24500

# %%
update_balance(1101,25000,"withdraw")
# Out:
# Insufficient balance!
# Transaction successful!

# %%
update_balance(1105,25000,"withdraw")
# Out:
# Account not found!

# %% [markdown]
# ## Conclusion :
#
# ###     This approach mirrors actual banking systems where customer data is efficiently managed.
#
# ### *     Understanding Dictionary operations and how function can reuse the code will prepares learner for database interaction and financial.
